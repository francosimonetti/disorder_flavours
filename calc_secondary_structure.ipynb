# %%
import os
import numpy as np
import pandas as pd
import umap
import time
import json
import requests
from Bio import SeqIO
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.patches import Patch
import mpl_stylesheet
mpl_stylesheet.banskt_presentation(fontfamily = 'mono', fontsize = 20, colors = 'banskt', dpi = 300)

target_uniprots = ["P37840", "P04637", "P02686", "P07305", "O00488", "Q9NYB9", "P06401", "Q16186", "S6B291", "P23441"]

# %%
### Load sequences and annotations for disprot

def get_sequences(fastadir=None, fastafile=None):
    sequences = []
    if fastadir is None and fastafile is None:
        print("No fasta dir or file")
        raise
    if fastadir is not None and fastafile is not None:
        print("Choose one, fasta dir or multi fasta filr")
        raise
    # check for a directory with individual fasta files
    # or a multi fasta file
    if fastadir is not None:
        fastafiles = os.listdir(fastadir)
        for f in fastafiles:
            counter = 0
            for record in SeqIO.parse(os.path.join(fastadir, f), "fasta"):
                sequences.append(record)
                counter += 1
                if counter > 1:
                    print("More than one fasta record?", f)
                    raise
    elif fastafile is not None:
        for record in SeqIO.parse(fastafile, "fasta"):
            sequences.append(record)
    return sequences

# Disprot
# embeddir="/data/franco/disorder_flavours/testset/" #"/data/franco/datasets/prot_embedding_weights/disprot/halft5/"
fasta_dir = "./disprot/fasta/" #"/data/franco/datasets/disprot/fasta/"
fasta_files = [f"{u}.fasta" for u in target_uniprots]
counter = 0

# find annotation for each sequence
annotfile = "./disprot/DisProt_release_2022_06_reformat_annot.fasta" #/data/franco/datasets/disprot/
annotdir  = None
annots    = get_sequences(fastadir=annotdir, fastafile=annotfile)
sequences = get_sequences(fastadir=fasta_dir, fastafile=None)

# %%
### Load monomer test proteins

# Monomers
fasta_file = "./disprot/monomers.fasta"
annotfile = "./disprot/monomers_annot.fasta"
annotdir  = None
mono_rannots    = get_sequences(fastadir=None, fastafile=annotfile)
mono_rsequences = get_sequences(fastadir=None, fastafile=fasta_file)

mono_seqs = list()
mono_annots = list()
mono_ids = list()

for i in range(len(mono_rsequences)):
    aa_seq = str(mono_rsequences[i].seq).upper()
    annot_seq = str(mono_rannots[i].seq)
    if len(aa_seq) == len(annot_seq):
        mono_ids.append(mono_rsequences[i].id)
        mono_seqs.append(aa_seq)
        mono_annots.append(annot_seq)
        if i>9:
            break

# %%
### Load more detailed annotation for disprot

import json
disprot_json_file = "./disprot/DisProt_release_2022_06_with_ambiguous_evidences.json"
with open(disprot_json_file) as infmt:
    json_dict = json.load(infmt)

json_dict['data'][1]['regions'][0]
print(json_dict['data'][1]["acc"])
# Out:
# P49913

# %%
### Subset target test proteins
disprot_datadict = dict()
for i in range(len(json_dict['data'])):
    if json_dict['data'][i]["acc"] in target_uniprots:
        disprot_datadict[json_dict['data'][i]["acc"]] = json_dict['data'][i]

# %%
### Make sure seq and annotations length match, and embed test proteins
annot_dict = dict()
for record in annots:
    if "|" in record.name:
        name = record.name.split("|")[1].strip()
    else:
        name = record.name.split()[0].strip()
        if name == "":
            print("Name is empty",record.name)
    annot_dict[name] = str(record.seq)
    
msequences  = list()
mannots     = list()
uniprots    = list()
counter = 0
for s in sequences:
    if "|" in s.name:
        uniprot_id = s.name.split("|")[1].strip()
    else:
        uniprot_id = s.name.split()[0].strip()
    if uniprot_id in target_uniprots:
        print(uniprot_id)
        aa_sequence = str(s.seq).upper()
        if len(aa_sequence) == len(annot_dict[uniprot_id]):
            uniprots.append(uniprot_id)
            msequences.append(aa_sequence)
            mannots.append(annot_dict[uniprot_id])
            counter += 1
        else:
            print("Seq length and annot do not match")
            print(len(annot_dict[uniprot_id]), uniprot_id, len(aa_sequence))
print(f"Loaded {counter} proteins")
# Out:
# S6B291
# P23441
# P04637
# Q16186
# P37840
# P07305
# P02686
# Q9NYB9
# P06401
# O00488
# Loaded 10 proteins

# %%
### Explore some detailed annotations
i=2
print(disprot_datadict[uniprots[i]]['disprot_consensus'])
print("##########")

for r in disprot_datadict[uniprots[i]]['regions']:
    print(r["term_namespace"])
    print(r["disprot_namespace"])
    print(r["term_name"])
    print(r["start"], r["end"])
    #print(r)
    print("########")

print(mannots[i])
## F: disorder Function, molecular Function
## D: disordered
## T: Structural Transition
# Out:
# {'full': [{'start': 1, 'end': 62, 'type': 'T'}, {'start': 63, 'end': 93, 'type': 'D'}, {'start': 291, 'end': 312, 'type': 'D'}, {'start': 359, 'end': 360, 'type': 'F'}, {'start': 361, 'end': 365, 'type': 'D'}, {'start': 366, 'end': 388, 'type': 'T'}, {'start': 389, 'end': 393, 'type': 'D'}], 'Structural state': [{'start': 1, 'end': 93, 'type': 'D'}, {'start': 291, 'end': 312, 'type': 'D'}, {'start': 361, 'end': 393, 'type': 'D'}], 'Molecular function': [{'start': 1, 'end': 93, 'type': 'F'}, {'start': 359, 'end': 393, 'type': 'F'}], 'Structural transition': [{'start': 1, 'end': 62, 'type': 'T'}, {'start': 366, 'end': 388, 'type': 'T'}], 'Disorder function': [{'start': 1, 'end': 61, 'type': 'F'}, {'start': 368, 'end': 372, 'type': 'F'}, {'start': 380, 'end': 384, 'type': 'F'}]}
# ##########
# Structural state
# Structural state
# disorder
# 1 12
# ########
# Structural state
# Structural state
# disorder
# 1 93
# ########
# Structural state
# Structural state
# disorder
# 291 312
# ########
# Structural state
# Structural state
# disorder
# 1 93
# ########
# Molecular function
# Disorder function
# protein binding
# 20 73
# ########
# Molecular function
# Disorder function
# molecular function activator activity
# 20 73
# ########
# Structural transition
# Structural transition
# disorder to order
# 37 57
# ########
# Molecular function
# Disorder function
# protein binding
# 37 57
# ########
# Structural transition
# Structural transition
# disorder to order
# 17 29
# ########
# Molecular function
# Disorder function
# protein binding
# 15 29
# ########
# Molecular function
# Disorder function
# protein binding
# 367 386
# ########
# Molecular function
# Disorder function
# protein binding
# 367 386
# ########
# Disorder function
# Disorder function
# acetylation display site
# 380 384
# ########
# Molecular function
# Disorder function
# molecular function activator activity
# 367 386
# ########
# Structural transition
# Structural transition
# disorder to order
# 367 386
# ########
# Molecular function
# Disorder function
# protein binding
# 47 58
# ########
# Structural transition
# Structural transition
# disorder to order
# 41 62
# ########
# Molecular function
# Disorder function
# protein binding
# 15 29
# ########
# Structural transition
# Structural transition
# disorder to order
# 17 27
# ########
# Molecular function
# Disorder function
# protein binding
# 1 93
# ########
# Molecular function
# Disorder function
# protein binding
# 1 93
# ########
# Molecular function
# Disorder function
# protein binding
# 1 93
# ########
# Structural transition
# Structural transition
# disorder to order
# 14 60
# ########
# Molecular function
# Disorder function
# protein binding
# 369 377
# ########
# Molecular function
# Disorder function
# protein binding
# 359 367
# ########
# Molecular function
# Disorder function
# protein binding
# 366 386
# ########
# Structural transition
# Structural transition
# disorder to order
# 366 386
# ########
# Molecular function
# Disorder function
# protein binding
# 366 386
# ########
# Molecular function
# Disorder function
# 14-3-3 protein binding
# 385 393
# ########
# Molecular function
# Disorder function
# protein binding
# 372 389
# ########
# Structural transition
# Structural transition
# disorder to order
# 375 385
# ########
# Molecular function
# Disorder function
# protein binding
# 367 388
# ########
# Structural transition
# Structural transition
# disorder to order
# 367 388
# ########
# Molecular function
# Disorder function
# protein binding
# 376 386
# ########
# Molecular function
# Disorder function
# protein binding
# 372 389
# ########
# Molecular function
# Disorder function
# protein binding
# 365 375
# ########
# Disorder function
# Disorder function
# methylation display site
# 368 372
# ########
# Molecular function
# Disorder function
# protein binding
# 379 385
# ########
# Molecular function
# Disorder function
# protein binding
# 1 39
# ########
# Structural transition
# Structural transition
# disorder to order
# 1 39
# ########
# Disorder function
# Disorder function
# phosphorylation display site
# 14 19
# ########
# Structural transition
# Structural transition
# disorder to order
# 42 56
# ########
# Molecular function
# Disorder function
# protein binding
# 42 56
# ########
# Structural state
# Structural state
# disorder
# 1 73
# ########
# Structural state
# Structural state
# disorder
# 1 73
# ########
# Molecular function
# Disorder function
# molecular function activator activity
# 1 73
# ########
# Molecular function
# Disorder function
# protein binding
# 1 73
# ########
# Structural state
# Structural state
# disorder
# 20 46
# ########
# Structural state
# Structural state
# disorder
# 56 70
# ########
# Structural state
# Structural state
# disorder
# 1 61
# ########
# Molecular function
# Disorder function
# protein binding
# 1 61
# ########
# Molecular function
# Disorder function
# protein binding
# 14 28
# ########
# Molecular function
# Disorder function
# protein binding
# 38 61
# ########
# Disorder function
# Disorder function
# self-inhibition
# 1 61
# ########
# Disorder function
# Disorder function
# self-inhibition
# 1 61
# ########
# Structural state
# Structural state
# disorder
# 361 393
# ########
# Structural state
# Structural state
# disorder
# 361 393
# ########
# TTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTTDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------DDDDDDDDDDDDDDDDDDDDDD----------------------------------------------FFDDDDDTTTTTTTTTTTTTTTTTTTTTTTDDDDD

# %%
### Secondary structure annotation

## Get PDBs and calculate Secondary structure for each using mkdssp
# what a pain to install!!

## Info about DSSP output
# https://pdb-redo.eu/dssp/about


for pdbidchain in mono_ids:
    pdbid = pdbidchain[:4]
    chain = pdbidchain[4]
    print(pdbid, chain)
    pdbfile = os.path.join("disprot","pdbs",pdbid+".pdb")
    res = requests.get(f"https://files.rcsb.org/download/{pdbid}.pdb")
    with open(pdbfile, 'w') as outfmt:
        outfmt.write(res.content.decode())

    dsspfile = os.path.join("disprot","pdbs",pdbid+".dssp")
    os.system(f"mkdssp --output-format dssp {pdbfile} {dsspfile}")

# %%
## Code to parse mkdssp output, not very optimal

def offset_loop(this_annot, counter, offset):
    dlen = 1
    while this_annot[counter+offset+1] == "D":
        offset += 1
        dlen += 1
    ss_list = ["-" for r in range(dlen)]
    return offset, ss_list

def parseDSSP(lines, targ_chain, this_seq, this_annot, debug=False):
    flagstart = False
    ss_seq = list()
    aa_seq = list()
    offset = 0
    targ_chain = "A"
    counter = 0
    for line in lines:
        if flagstart:
            if line == "":
                break
            resnum = line[:5]
            pdbresnum = line[5:10]
            chain = line[11]
            resname = line[13]
            ss = line[16]
            end = line[14]
            if debug:
                print(f"--> counter:{counter}, offset:{offset}",resnum, pdbresnum, chain, resname, ss, "||", line[1:17])
            if end == "*":
                break
            if resname != "!":
                if chain == targ_chain:
                    if resname == this_seq[counter+offset]:
                        if ss == " ":
                            ss = "-"
                        ss_seq.append(ss)
                        aa_seq.append(resname)
                        if debug:
                            print(f"---> {resname} === {this_seq[counter+offset]}")
                    else:
                        if this_annot[counter+offset] == "D":
                            if debug:
                                print(f" {resname} != {this_seq[counter+offset]} -->OFFSET LOOP: counter:{counter}, offset:{offset}")
                            #ss_seq.append("-")
                            if this_annot[counter+offset+1] == "D" and len(this_annot) >= (counter+offset+1):
                                offset, ss_list = offset_loop(this_annot, counter, offset)
                                if debug:
                                    print(f"END OFFSET LOOP: counter:{counter}, offset:{offset}")
                                for s in ss_list:
                                    ss_seq.append(s)
                                    aa_seq.append("-")
                                if counter == 0:
                                    offset += 1
                                    if resname == this_seq[counter+offset]:
                                        if ss == " ":
                                            ss = "-"
                                        ss_seq.append(ss)
                                        aa_seq.append(resname)
                        else:
                            ss = "-"
                            ss_seq.append(ss)
                            aa_seq.append(resname)
                            if debug:
                                print(f"MISMATCH?? {resname} ?? {this_seq[counter+offset]}")
                else:
                    print("PANIC")
                    raise
            else:
                if debug:
                    print(f"resname == '!' --> counter:{counter}, offset:{offset} '-' {this_seq[counter+offset]}")
                #ss_seq.append("-")
                if this_annot[counter+offset+1] == "D" and len(this_annot) >= (counter+offset+1):
                    offset, ss_list = offset_loop(this_annot, counter, offset)
                    for s in ss_list:
                        ss_seq.append(s)
                        aa_seq.append("-")
                else:
                    print("PANIC")
                    raise           
            counter += 1
        if line.strip().startswith("#"):
            flagstart = True
            
    diff = len(ss_seq) - len(this_seq)
    if diff > 0:
        print("DSSP is longer than seq?")
    if diff < 0:
        print(f"DSSP is missing some residues? missing:{diff}")
        ## If it's missing some residue ss, just add it to the end. This is not very good
        for i in range(np.abs(diff)):
            ss_seq.append("-")
    return ss_seq, aa_seq

# %%
## parse output files
## Parse secondary structure
# make sure sequences matches
mono_dssps = list()
for i, pdbidchain in enumerate(mono_ids):
    pdbid = pdbidchain[:4]
    dsspfile = os.path.join("disprot","pdbs",pdbid+".dssp")
    with open(dsspfile) as infmt:
        lines = infmt.readlines()
    print(pdbid, pdbidchain[4])
    mono_ss_seq, _aa_seq = parseDSSP(lines, pdbidchain[4], mono_seqs[i], mono_annots[i])
    mono_dssps.append("".join(mono_ss_seq))

# %%
## Check ss and seq len are the same at least
for i in range(11):
    print(f"### {mono_ids[i]}")
    print("seqlen:", len(mono_seqs[i]),"dssp_len:", len(mono_dssps[i]))

# %%
## Some debugging
i = 9
pdbidchain = mono_ids[i]
pdbid = pdbidchain[:4]
print(pdbidchain)
dsspfile = os.path.join("disprot","pdbs",pdbid+".dssp")
with open(dsspfile) as infmt:
    lines = infmt.readlines()
ss_seq, _aa_seq = parseDSSP(lines, pdbidchain[4], mono_seqs[i], mono_annots[i], debug=True)

print(f"### {mono_ids[i]}")
print(mono_annots[i])
print("".join(mono_dssps[i]))
print("seqlen:", len(mono_seqs[i]),"dssp_len:", len("".join(mono_dssps[i])))

# %%
### Obtain SS annotations from PDB website

ssannots_list = list()
for i in range(len(mono_ids)):
    annots = list()
    pdbidchain = mono_ids[i]
    pdbid = pdbidchain[:4]
    chain = pdbidchain[4]
    print(pdbid, chain)
    res = requests.get(f"https://data.rcsb.org/rest/v1/core/polymer_entity_instance/{pdbid.upper()}/{chain.upper()}")
    datadict = json.loads(res.content.decode())
    
    for e in datadict["rcsb_polymer_instance_feature"]:
        if 'provenance_source' in e:
            if e['provenance_source'] == "PROMOTIF":
                ss_type  = e['type']
                for ee in e['feature_positions']:
                    ss_begin = ee["beg_seq_id"]
                    ss_end   = ee["end_seq_id"]
                    #print(ss_type, ss_begin, ss_end)
                    annots.append([ss_type, ss_begin, ss_end])
            if e['provenance_source'] == "PDB":
                if e["type"] == "UNOBSERVED_RESIDUE_XYZ":
                    for ee in e['feature_positions']:
                        miss_begin = ee["beg_seq_id"]
                        miss_end   = ee["end_seq_id"]
                        #print("MISSING", miss_begin, miss_end)
                        annots.append(["MISSING", miss_begin, miss_end])
    ssannots_list.append(annots)
# Out:
# 1AE9 A
# SHEET 48 49
# SHEET 52 56
# SHEET 63 67
# SHEET 173 176
# SHEET 70 72
# SHEET 77 79
# SHEET 167 168
# SHEET 173 176
# HELIX_P 6 18
# HELIX_P 22 33
# HELIX_P 37 42
# HELIX_P 79 89
# HELIX_P 106 120
# HELIX_P 133 145
# HELIX_P 148 155
# UNASSIGNED_SEC_STRUCT 1 5
# UNASSIGNED_SEC_STRUCT 19 21
# UNASSIGNED_SEC_STRUCT 34 36
# UNASSIGNED_SEC_STRUCT 43 47
# UNASSIGNED_SEC_STRUCT 50 51
# UNASSIGNED_SEC_STRUCT 57 62
# UNASSIGNED_SEC_STRUCT 68 69
# UNASSIGNED_SEC_STRUCT 73 76
# UNASSIGNED_SEC_STRUCT 90 105
# UNASSIGNED_SEC_STRUCT 121 132
# UNASSIGNED_SEC_STRUCT 146 147
# UNASSIGNED_SEC_STRUCT 156 166
# UNASSIGNED_SEC_STRUCT 169 172
# UNASSIGNED_SEC_STRUCT 177 179
# MISSING 159 165
# 1AH7 A
# HELIX_P 14 27
# HELIX_P 35 52
# HELIX_P 86 103
# HELIX_P 106 122
# HELIX_P 126 130
# HELIX_P 141 148
# HELIX_P 173 186
# HELIX_P 193 204
# HELIX_P 206 242
# UNASSIGNED_SEC_STRUCT 1 13
# UNASSIGNED_SEC_STRUCT 28 34
# UNASSIGNED_SEC_STRUCT 53 85
# UNASSIGNED_SEC_STRUCT 104 105
# UNASSIGNED_SEC_STRUCT 123 125
# UNASSIGNED_SEC_STRUCT 131 140
# UNASSIGNED_SEC_STRUCT 149 172
# UNASSIGNED_SEC_STRUCT 187 192
# UNASSIGNED_SEC_STRUCT 205 205
# UNASSIGNED_SEC_STRUCT 243 245
# 1AHO A
# SHEET 33 37
# SHEET 45 49
# HELIX_P 19 28
# UNASSIGNED_SEC_STRUCT 1 18
# UNASSIGNED_SEC_STRUCT 29 32
# UNASSIGNED_SEC_STRUCT 38 44
# UNASSIGNED_SEC_STRUCT 50 64
# 1AOC A
# SHEET 90 93
# SHEET 124 127
# SHEET 99 101
# SHEET 107 109
# SHEET 139 153
# SHEET 158 173
# HELIX_P 24 39
# HELIX_P 48 50
# HELIX_P 55 60
# HELIX_P 70 73
# HELIX_P 75 77
# UNASSIGNED_SEC_STRUCT 1 23
# UNASSIGNED_SEC_STRUCT 40 47
# UNASSIGNED_SEC_STRUCT 51 54
# UNASSIGNED_SEC_STRUCT 61 69
# UNASSIGNED_SEC_STRUCT 74 74
# UNASSIGNED_SEC_STRUCT 78 89
# UNASSIGNED_SEC_STRUCT 94 98
# UNASSIGNED_SEC_STRUCT 102 106
# UNASSIGNED_SEC_STRUCT 110 123
# UNASSIGNED_SEC_STRUCT 128 138
# UNASSIGNED_SEC_STRUCT 154 157
# UNASSIGNED_SEC_STRUCT 174 175
# 1AOL A
# SHEET 139 143
# SHEET 110 114
# SHEET 197 203
# SHEET 211 221
# SHEET 2 10
# SHEET 16 25
# SHEET 155 159
# SHEET 179 183
# HELIX_P 37 41
# HELIX_P 46 48
# HELIX_P 77 80
# HELIX_P 93 104
# HELIX_P 120 125
# HELIX_P 128 130
# HELIX_P 163 171
# HELIX_P 185 189
# HELIX_P 192 194
# HELIX_P 224 226
# UNASSIGNED_SEC_STRUCT 1 1
# UNASSIGNED_SEC_STRUCT 11 15
# UNASSIGNED_SEC_STRUCT 26 36
# UNASSIGNED_SEC_STRUCT 42 45
# UNASSIGNED_SEC_STRUCT 49 76
# UNASSIGNED_SEC_STRUCT 81 92
# UNASSIGNED_SEC_STRUCT 105 109
# UNASSIGNED_SEC_STRUCT 115 119
# UNASSIGNED_SEC_STRUCT 126 127
# UNASSIGNED_SEC_STRUCT 131 138
# UNASSIGNED_SEC_STRUCT 144 154
# UNASSIGNED_SEC_STRUCT 160 162
# UNASSIGNED_SEC_STRUCT 172 178
# UNASSIGNED_SEC_STRUCT 184 184
# UNASSIGNED_SEC_STRUCT 190 191
# UNASSIGNED_SEC_STRUCT 195 196
# UNASSIGNED_SEC_STRUCT 204 210
# UNASSIGNED_SEC_STRUCT 222 223
# UNASSIGNED_SEC_STRUCT 227 228
# 1AQZ A
# SHEET 2 8
# SHEET 19 25
# SHEET 49 51
# SHEET 92 97
# SHEET 119 125
# SHEET 130 136
# SHEET 144 146
# HELIX_P 26 35
# HELIX_P 73 76
# UNASSIGNED_SEC_STRUCT 1 1
# UNASSIGNED_SEC_STRUCT 9 18
# UNASSIGNED_SEC_STRUCT 36 48
# UNASSIGNED_SEC_STRUCT 52 72
# UNASSIGNED_SEC_STRUCT 77 91
# UNASSIGNED_SEC_STRUCT 98 118
# UNASSIGNED_SEC_STRUCT 126 129
# UNASSIGNED_SEC_STRUCT 137 143
# UNASSIGNED_SEC_STRUCT 147 149
# MISSING 11 17
# 1ATG A
# SHEET 29 34
# SHEET 2 7
# SHEET 51 53
# SHEET 191 196
# SHEET 75 79
# SHEET 161 164
# SHEET 82 86
# SHEET 178 180
# SHEET 107 110
# SHEET 140 143
# HELIX_P 8 25
# HELIX_P 36 44
# HELIX_P 58 65
# HELIX_P 97 100
# HELIX_P 116 128
# HELIX_P 131 136
# HELIX_P 146 154
# HELIX_P 165 167
# HELIX_P 203 214
# HELIX_P 216 224
# UNASSIGNED_SEC_STRUCT 1 1
# UNASSIGNED_SEC_STRUCT 26 28
# UNASSIGNED_SEC_STRUCT 35 35
# UNASSIGNED_SEC_STRUCT 45 50
# UNASSIGNED_SEC_STRUCT 54 57
# UNASSIGNED_SEC_STRUCT 66 74
# UNASSIGNED_SEC_STRUCT 80 81
# UNASSIGNED_SEC_STRUCT 87 96
# UNASSIGNED_SEC_STRUCT 101 106
# UNASSIGNED_SEC_STRUCT 111 115
# UNASSIGNED_SEC_STRUCT 129 130
# UNASSIGNED_SEC_STRUCT 137 139
# UNASSIGNED_SEC_STRUCT 144 145
# UNASSIGNED_SEC_STRUCT 155 160
# UNASSIGNED_SEC_STRUCT 168 177
# UNASSIGNED_SEC_STRUCT 181 190
# UNASSIGNED_SEC_STRUCT 197 202
# UNASSIGNED_SEC_STRUCT 215 215
# UNASSIGNED_SEC_STRUCT 225 231
# 1ATZ A
# SHEET 165 167
# SHEET 136 143
# SHEET 109 116
# SHEET 6 13
# SHEET 44 51
# SHEET 55 59
# HELIX_P 20 36
# HELIX_P 67 75
# HELIX_P 86 98
# HELIX_P 125 133
# HELIX_P 149 155
# HELIX_P 172 178
# HELIX_P 182 185
# UNASSIGNED_SEC_STRUCT 1 5
# UNASSIGNED_SEC_STRUCT 14 19
# UNASSIGNED_SEC_STRUCT 37 43
# UNASSIGNED_SEC_STRUCT 52 54
# UNASSIGNED_SEC_STRUCT 60 66
# UNASSIGNED_SEC_STRUCT 76 85
# UNASSIGNED_SEC_STRUCT 99 108
# UNASSIGNED_SEC_STRUCT 117 124
# UNASSIGNED_SEC_STRUCT 134 135
# UNASSIGNED_SEC_STRUCT 144 148
# UNASSIGNED_SEC_STRUCT 156 164
# UNASSIGNED_SEC_STRUCT 168 171
# UNASSIGNED_SEC_STRUCT 179 181
# UNASSIGNED_SEC_STRUCT 186 189
# MISSING 1 3
# MISSING 188 189
# 1AYO B
# SHEET 4 11
# SHEET 23 32
# SHEET 89 97
# SHEET 52 54
# SHEET 120 125
# SHEET 107 113
# SHEET 42 47
# SHEET 76 81
# SHEET 67 73
# HELIX_P 18 21
# HELIX_P 56 64
# UNASSIGNED_SEC_STRUCT 1 3
# UNASSIGNED_SEC_STRUCT 12 17
# UNASSIGNED_SEC_STRUCT 22 22
# UNASSIGNED_SEC_STRUCT 33 41
# UNASSIGNED_SEC_STRUCT 48 51
# UNASSIGNED_SEC_STRUCT 55 55
# UNASSIGNED_SEC_STRUCT 65 66
# UNASSIGNED_SEC_STRUCT 74 75
# UNASSIGNED_SEC_STRUCT 82 88
# UNASSIGNED_SEC_STRUCT 98 106
# UNASSIGNED_SEC_STRUCT 114 119
# UNASSIGNED_SEC_STRUCT 126 130
# 1AZO A
# SHEET 80 86
# SHEET 123 129
# SHEET 144 147
# SHEET 184 187
# SHEET 213 216
# SHEET 96 100
# SHEET 197 200
# SHEET 206 209
# HELIX_P 17 27
# HELIX_P 32 39
# HELIX_P 53 61
# HELIX_P 72 75
# HELIX_P 115 119
# HELIX_P 136 138
# HELIX_P 151 169
# HELIX_P 173 175
# HELIX_P 218 229
# UNASSIGNED_SEC_STRUCT 1 16
# UNASSIGNED_SEC_STRUCT 28 31
# UNASSIGNED_SEC_STRUCT 40 52
# UNASSIGNED_SEC_STRUCT 62 71
# UNASSIGNED_SEC_STRUCT 76 79
# UNASSIGNED_SEC_STRUCT 87 95
# UNASSIGNED_SEC_STRUCT 101 114
# UNASSIGNED_SEC_STRUCT 120 122
# UNASSIGNED_SEC_STRUCT 130 135
# UNASSIGNED_SEC_STRUCT 139 143
# UNASSIGNED_SEC_STRUCT 148 150
# UNASSIGNED_SEC_STRUCT 170 172
# UNASSIGNED_SEC_STRUCT 176 183
# UNASSIGNED_SEC_STRUCT 188 196
# UNASSIGNED_SEC_STRUCT 201 205
# UNASSIGNED_SEC_STRUCT 210 212
# UNASSIGNED_SEC_STRUCT 217 217
# UNASSIGNED_SEC_STRUCT 230 232
# MISSING 1 6
# MISSING 65 69
# MISSING 189 195
# 1B9W A
# SHEET 16 20
# SHEET 26 30
# SHEET 34 37
# SHEET 40 43
# SHEET 61 64
# SHEET 70 73
# SHEET 79 82
# HELIX_P 3 5
# HELIX_P 52 55
# HELIX_P 83 85
# UNASSIGNED_SEC_STRUCT 1 2
# UNASSIGNED_SEC_STRUCT 6 15
# UNASSIGNED_SEC_STRUCT 21 25
# UNASSIGNED_SEC_STRUCT 31 33
# UNASSIGNED_SEC_STRUCT 38 39
# UNASSIGNED_SEC_STRUCT 44 51
# UNASSIGNED_SEC_STRUCT 56 60
# UNASSIGNED_SEC_STRUCT 65 69
# UNASSIGNED_SEC_STRUCT 74 78
# UNASSIGNED_SEC_STRUCT 86 95
# MISSING 92 95

# %%
## Change the annotation from regions to letter sequences
mono_easydssp = list()
for i in range(len(mono_ids)):
    #print(ssannots_list[i])
    ss_placeholder = ["-" for i in range(len(mono_seqs[i]))]
    for a in ssannots_list[i]:
        letter = "-"
        if a[0].startswith("HELIX"):
            letter = "H"
        if a[0].startswith("SHEET"):
            letter = "B"
        for j in range(int(a[1]), int(a[2])):
            ss_placeholder[j] = letter
    mono_easydssp.append("".join(ss_placeholder))

# %%
# Compare with mkdssp, it was very similar.. ish. DSSP gives more detailed information 
# but the overall ranges match

for i in range(len(mono_ids)):
    #print(mono_dssps[i])
    print(mono_easydssp[i])
    print("~~~")
# Out:
# ------HHHHHHHHHHHH----HHHHHHHHHHH----HHHHH------B---BBBB-------BBBB---BB-----BBHHHHHHHHHH-----------------HHHHHHHHHHHHHH-------------HHHHHHHHHHHH---HHHHHHH------------B-----BBB---
# ~~~
# --------------HHHHHHHHHHHHH--------HHHHHHHHHHHHHHHHH----------------------------------HHHHHHHHHHHHHHHHH---HHHHHHHHHHHHHHHH----HHHH-----------HHHHHHH-------------------------HHHHHHHHHHHHH-------HHHHHHHHHHH--HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH---
# ~~~
# -------------------HHHHHHHHH-----BBBB--------BBBB---------------
# ~~~
# ------------------------HHHHHHHHHHHHHHH---------HH-----HHHHH----------HHH--HH-------------BBB------BB------BB---------------BBB------------BBBBBBBBBBBBBB-----BBBBBBBBBBBBBBB--
# ~~~
# --BBBBBBBB------BBBBBBBBB------------HHHH-----HH-----------------------------HHH-------------HHHHHHHHHHH------BBBB------HHHHH---HH---------BBBB------------BBBB----HHHHHHHH--------BBBB--HHHH---HH---BBBBBB--------BBBBBBBBBB---HH--
# ~~~
# --BBBBBB-----------BBBBBB-HHHHHHHHH--------------BB----------------------HHH----------------BBBBB----------------------BBBBBB-----BBBBBB--------BB---
# ~~~
# --BBBBB-HHHHHHHHHHHHHHHHH----BBBBB--HHHHHHHH-------BB-----HHHHHHH----------BBBB---BBBB-----------HHH-------BBB------HHHHHHHHHHHH---HHHHH----BBB---HHHHHHHH-------BBB-HH-----------BB-----------BBBBB-------HHHHHHHHHHH--HHHHHHHH-------
# ~~~
# ------BBBBBBB-------HHHHHHHHHHHHHHHH--------BBBBBBB----BBBB--------HHHHHHHH-----------HHHHHHHHHHHH-----------BBBBBBB---------HHHHHHHH---BBBBBBB------HHHHHH----------BB-----HHHHHH----HHH----
# ~~~
# ----BBBBBBB-------HHH--BBBBBBBBB----------BBBBB-----BB--HHHHHHHH---BBBBBB---BBBBB--------BBBBBBBB----------BBBBBB-------BBBBB-----
# ~~~
# -----------------HHHHHHHHHH-----HHHHHHH--------------HHHHHHHH-----------HHH-----BBBBBB----------BBBB---------------HHHH----BBBBBB-------HH------BBB----HHHHHHHHHHHHHHHHHH----HH---------BBB----------BBB------BBB----BBB--HHHHHHHHHHH---
# ~~~
# ---HH-----------BBBB------BBBB----BBB---BBB---------HHH------BBB------BBB------BBB-HH----------
# ~~~
