# %%
from Bio import SeqIO
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.patches import Patch
import mpl_stylesheet
mpl_stylesheet.banskt_presentation(fontfamily = 'mono', fontsize = 20, colors = 'banskt', dpi = 300)

def get_kmers(seq, K=30):
    start = 0
    end   = len(seq)
    kmers = list()
    ranges= list()
    for i in range(start, end):
        if i > len(seq)-K or ((i+K)>len(seq)):
            break
        else:
            kmers.append(seq[i:i+K])
            ranges.append(f"{i}_{i+K}")
    return kmers, ranges

def get_sequences(fastadir=None, fastafile=None):
    sequences = []
    if fastadir is None and fastafile is None:
        print("No fasta dir or file")
        raise
    if fastadir is not None and fastafile is not None:
        print("Choose one, fasta dir or multi fasta filr")
        raise
    # check for a directory with individual fasta files
    # or a multi fasta file
    if fastadir is not None:
        fastafiles = os.listdir(fastadir)
        for f in fastafiles:
            counter = 0
            for record in SeqIO.parse(os.path.join(fastadir, f), "fasta"):
                sequences.append(record)
                counter += 1
                if counter > 1:
                    print("More than one fasta record?", f)
                    raise
    elif fastafile is not None:
        for record in SeqIO.parse(fastafile, "fasta"):
            sequences.append(record)
    return sequences

# %%
dataset_name="disprot"
upix = 1
Ks = [30]
fastafile=None
fastadir="/data/franco/datasets/disprot/fasta/"
annotdir=None
annotfile="/data/franco/datasets/disprot/DisProt_release_2022_06_reformat_annot.fasta"


sequences = get_sequences(fastadir=fastadir, fastafile=fastafile)
annots    = get_sequences(fastadir=annotdir, fastafile=annotfile)

# find annotation for each sequence
# read annotation data first
annot_dict = dict()
for record in annots:
    if "|" in record.name:
        name = record.name.split("|")[upix].strip()
    else:
        name = record.name.strip()
        if name == "":
            print("Name is empty",record.name)
            raise
    # if name != "A0A6L8PPD0":
    #     continue
    annot_dict[name] = str(record.seq)

# %%
selected_sequences = []
disseqs = list()
selected_uniprots = list()

for s in sequences:
    if "|" in s.name:
        name = s.name.split("|")[upix].strip()
    else:
        name = s.name.strip()
        if name == "":
            print("Name is empty",s.name)
            raise
    # print(f"Loading {name} data")
    aa_sequence = str(s.seq).upper()
    if len(aa_sequence) > 1200:
        print(f"Skipping {name}, len={len(aa_sequence)}")
        continue
    if len(s.seq) == len(annot_dict[name]):
            disseqs.append(annot_dict[name])
            selected_sequences.append(aa_sequence)
            selected_uniprots.append(name)
    else:
        print("Sequence and annotation length do not match")
        print(len(s.seq), len(annot_dict[name]), name)
# Out:
# Skipping Q9NRR4, len=1374
# Skipping Q9C000, len=1473
# Skipping P12296, len=2293
# Skipping P49790, len=1475
# Skipping Q03834, len=1242
# Skipping P12823, len=3388
# Skipping Q00955, len=2233
# Skipping C4R4Y0, len=1743
# Skipping Q96T58, len=3664
# Skipping P70365, len=1447
# Skipping O95405, len=1425
# Skipping P08581, len=1390
# Skipping P46674, len=1301
# Skipping Q09427, len=1582
# Skipping Q04637-8, len=1600
# Skipping P08799, len=2116
# Skipping Q00496, len=1251
# Skipping P14340, len=3391
# Skipping P03305, len=2332
# Skipping Q9Q6P4, len=3433
# Sequence and annotation length do not match
# 194 259 Q12983
# Skipping D1A4G7, len=1315
# Skipping Q7B8V4, len=1296
# Skipping Q05022, len=1729
# Skipping P29990, len=3391
# Skipping A5YV76, len=2512
# Skipping Q6A070, len=1776
# Skipping P31327, len=1500
# Skipping Q32ZE1, len=3419
# Skipping P0DTD1, len=7096
# Skipping P0C6X7, len=7073
# Skipping O60706-2, len=1549
# Skipping P15941, len=1255
# Skipping P21333, len=2647
# Skipping A7ZUK2, len=1407
# Skipping Q09472, len=2414
# Skipping P03316, len=1245
# Skipping O86488, len=1315
# Skipping P30996, len=1274
# Skipping P49327, len=2511
# Skipping O95071, len=2799
# Skipping A4L7I4, len=2474
# Skipping P29375, len=1690
# Skipping P14335, len=3433
# Skipping P32521, len=1480
# Skipping Q9HAU5, len=1272
# Skipping P52179, len=1685
# Skipping Q9UGL1, len=1544
# Skipping P40477, len=1460
# Skipping P32004, len=1257
# Skipping Q02388, len=2944
# Skipping Q96MS0, len=1386
# Skipping Q80UG2, len=1893
# Skipping P80457, len=1332
# Skipping O17428, len=1807
# Skipping Q6URW6, len=2000
# Skipping Q925J9, len=1575
# Skipping P08775, len=1970
# Skipping Q8TEQ6, len=1508
# Skipping P49687, len=1317
# Skipping P46531, len=2555
# Skipping P0DTC2, len=1273
# Skipping Q14191, len=1432
# Skipping P27958, len=3011
# Skipping P10686, len=1290
# Skipping Q868N5, len=1770
# Skipping P17763, len=3392
# Skipping P10587, len=1979
# Skipping Q86YV5, len=1406
# Skipping Q9C0C7, len=1298
# Skipping P04275, len=2813
# Skipping Q07889, len=1333
# Skipping P35916, len=1363
# Skipping P28827, len=1452
# Skipping Q9UPY3, len=1922
# Skipping Q01097, len=1482
# Skipping O14187, len=2363
# Skipping P24928, len=1970
# Skipping Q92793, len=2442
# Skipping Q5VZK9, len=1371
# Skipping P54132, len=1417
# Skipping I1WVY3, len=3122
# Skipping Q8CJF7, len=2243
# Skipping P28023, len=1280
# Skipping Q01484, len=3957
# Skipping Q9Y6Q9, len=1424
# Skipping P22219, len=1454
# Skipping P51825, len=1210
# Skipping P51587, len=3418
# Skipping Q8K368, len=1330
# Skipping P12497, len=1435
# Skipping Q9SP32, len=1909
# Skipping P32639, len=2163
# Skipping O60885, len=1362
# Skipping Q64487-12, len=1501
# Skipping Q15596, len=1464
# Skipping P04050, len=1733
# Skipping P08392, len=1298
# Skipping Q05471, len=1514
# Skipping Q8TEK3, len=1537
# Skipping P78504, len=1218
# Skipping P00533, len=1210
# Skipping A5HC98, len=2263
# Skipping O14727, len=1248
# Skipping P59594, len=1255
# Skipping O92972, len=3010
# Skipping Q99250, len=2005
# Skipping A3RMR8, len=2474
# Skipping P38398, len=1863
# Skipping P35207, len=1287
# Skipping P29539, len=1916
# Skipping P06935, len=3430
# Skipping Q6R327, len=1708
# Skipping P02549, len=2419
# Skipping Q03164, len=3969
# Skipping Q6VMQ6, len=1270
# Skipping P15146, len=1861
# Skipping K9N5Q8, len=1353
# Skipping P27284, len=1240
# Skipping Q24298, len=1507
# Skipping Q8VHK2, len=1430
# Skipping P53420, len=1690
# Skipping Q09428, len=1581
# Skipping P10071, len=1580
# Skipping Q84852, len=1225
# Skipping Q8WZ42, len=34350
# Skipping Q03132, len=3567
# Skipping O46385, len=2194
# Skipping O81283, len=1503
# Skipping Q9WMX2, len=3010
# Skipping P33334, len=2413
# Skipping Q9H2Y7, len=1883
# Skipping J7QLC0, len=1706
# Skipping A4L7I2, len=2474
# Skipping Q920Q2, len=1249
# Skipping P21675, len=1872
# Skipping Q48245, len=1287
# Skipping Q9BE39, len=1935
# Skipping Q5UB51, len=3390
# Sequence and annotation length do not match
# 565 599 Q9UJX3
# Skipping P07293, len=1873
# Skipping Q9SLF3, len=1206
# Skipping Q2YHF0, len=3387
# Skipping P13569, len=1480
# Skipping Q04656, len=1500
# Skipping Q7X2A1, len=1889
# Sequence and annotation length do not match
# 121 129 Q9NX55
# Skipping P47054, len=1683
# Skipping Q9HAV4, len=1204
# Skipping P07248, len=1323
# Skipping P21447, len=1276
# Skipping P09546, len=1320
# Skipping P06491, len=1374
# Skipping P04775, len=2005
# Skipping P51123, len=2129
# Skipping G0S3L5, len=2297
# Skipping Q7RTP6, len=2002
# Skipping Q69422, len=2864
# Skipping P11274, len=1271
# Skipping Q2TAZ0, len=1938
# Skipping P03315, len=1253
# Skipping O75533, len=1304
# Skipping Q8NG31, len=2342
# Skipping Q8TDY2, len=1594
# Skipping P25054, len=2843
# Skipping P34369, len=2329
# Skipping P04626, len=1255
# Skipping Q13464, len=1354
# Skipping P38968, len=1273
# Skipping Q9HCJ0, len=1690
# Skipping Q28146, len=1530
# Skipping P26039, len=2541
# Skipping P45481, len=2441
# Skipping Q01970, len=1234
# Skipping Q25733, len=2924
# Skipping Q04637, len=1599
# Skipping A5YKK6, len=2376
# Skipping Q12888, len=1972
# Skipping P06786, len=1428
# Skipping P52948, len=1817
# Skipping O00411, len=1230
# Skipping P84634, len=1702
# Skipping P05661, len=1962
# Skipping P0DOC6, len=1389
# Skipping G5ED39, len=1262
# Skipping O60486, len=1568
# Skipping Q8WYP5, len=2266
# Skipping C4PB33, len=1772
# Skipping P05769, len=3434
# Skipping Q13029, len=1718
# Skipping P19711, len=3988
# Skipping A0A5F9ZHA1, len=1849
# Skipping P34712, len=1321
# Skipping Q9V6K1, len=1441
# Skipping P27708, len=2225
# Skipping P36594, len=1752
# Skipping Q99IB8, len=3033
# Skipping P04052, len=1887
# Skipping Q13698, len=1873
# Sequence and annotation length do not match
# 748 808 Q03518
# Skipping P24785, len=1293
# Skipping Q8WVM7, len=1258

# %%
len(selected_uniprots)
# Out:
# 2214

# %%
fastafile = "kmer_analysis_data/disprot_kmers30.fasta"
fastadir = None

disprot_kmers = get_sequences(fastadir=fastadir, fastafile=fastafile)

fastafile = "kmer_analysis_data/disprot_annot_kmers30.fasta"
fastadir = None

disprot_annot_kmers = get_sequences(fastadir=fastadir, fastafile=fastafile)

# %%
kmer_dict = dict()
kmer_annot_dict = dict()
for r in disprot_kmers:
    kmer_dict[r.name] = str(r.seq)
    
for r in disprot_annot_kmers:
    kmer_annot_dict[r.name] = str(r.seq)

# %%
kmer_files = os.listdir("disprot_kmers30/halft5/")

# %%
print(len(kmer_files))
print(len(kmer_annot_dict.keys()))
print(len(kmer_dict.keys()))
# Out:
# 839065
# 839065
# 839065

# %%
def list_saver(mylist, outfile):
    with open(outfile, 'w') as outfmt:
        for e in mylist:
            outfmt.write(e)
    return None

annot_out = "/data/franco/disorder_flavours/disprot_kmers30/kmer_disorder_contents.txt"
list_saver([f"{e:.2f}" for e in kmer_disorder_contents], annot_out)

# %%
myumap         = umap.UMAP(n_neighbors=100, min_dist=0.2, densmap=True)
densumap_coord = myumap.fit_transform(np.array(whole_kmer_embeddings))
