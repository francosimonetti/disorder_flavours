# %%
import matplotlib.pyplot as plt
import requests
import json
from Bio import SeqIO
import os
import time
import collections
os.chdir("/biodata/franco/zsuzsa_lab/jupyter")

# Read the file disprot_OK_fullset.fasta and get all the identifiers
identifiers = []

disprot_dict = collections.defaultdict(dict)

with open("/biodata/franco/datasets/disprot/disprot_OK_fullset_2023_12.fasta") as instrm:
    for record in SeqIO.parse(instrm, "fasta"):
            disprot_dict[record.id]['seq'] = str(record.seq)
            identifiers.append(record.id)
with open("/biodata/franco/datasets/disprot/disprot_OK_fullset_annotations_2023_12.fasta") as instrm:
    for record in SeqIO.parse(instrm, "fasta"):
            disprot_dict[record.id]['disorder'] = str(record.seq)

# %%
import re
def remove_letters(num):
    return int(re.sub("[^0-9]", "", str(num)))

def parse_pdb_json(datadict, pdbid, chain):
    annots = []

    if "rcsb_polymer_instance_feature" not in datadict:
        print(f"Error with {pdbid}_{chain}")
        return False, False
    else:
        # get sequence numbering
        seqres_num = datadict['rcsb_polymer_entity_instance_container_identifiers']['auth_to_entity_poly_seq_mapping']
        seqres_num = [remove_letters(n) for n in seqres_num]
        for e in datadict["rcsb_polymer_instance_feature"]:
            if 'provenance_source' in e:
                if e['provenance_source'] == "PROMOTIF":
                    ss_type  = e['type']
                    for ee in e['feature_positions']:
                        ss_begin = remove_letters(ee["beg_seq_id"])
                        ss_end   = remove_letters(ee["end_seq_id"])
                        #print(ss_type, ss_begin, ss_end)
                        annots.append([ss_type, ss_begin, ss_end])
                if e['provenance_source'] == "PDB":
                    if e["type"] == "UNOBSERVED_RESIDUE_XYZ":
                        for ee in e['feature_positions']:
                            miss_begin = remove_letters(ee["beg_seq_id"])
                            miss_end   = remove_letters(ee["end_seq_id"])
                            #print("MISSING", miss_begin, miss_end)
                            annots.append(["MISSING", miss_begin, miss_end])
        return seqres_num, annots

def parse_annots_to_seq(annot, disprot_dict, uniprot_id, seqres_num):
    ss_placeholder = ["-" for i in range(len(disprot_dict[uniprot_id]['seq']))]
    #seqres_num = ssresnum_list[i]
    for a in annot:
        letter = "-"
        if a[0].startswith("UNASSIGNED"):
            letter = "U"
        if a[0].startswith("MISSING"):
            letter = "M"
        if a[0].startswith("HELIX"):
            letter = "H"
        if a[0].startswith("SHEET"):
            letter = "B"
        for j in range(int(a[1])-1, int(a[2])): # numbering starts at 1 in pdb, so start counting one before, ie 1 is 0
            try:
                ss_placeholder[j] = letter
            except:
                print(f"Error with {uniprot_id}")
                print(f"Annot: {a}")
                print(f"Seq: {disprot_dict[uniprot_id]['seq']}")
                print(f"SS: {len(ss_placeholder)}")
                return False
    return ss_placeholder

def parse_annots_to_seq2(annot, disprot_dict, uniprot_id, seqres_num):
    ss_placeholder = ["-" for i in range(len(disprot_dict[uniprot_id]['seq']))]
    #seqres_num = ssresnum_list[i]
    for a in annot:
        letter = "-"
        if a[0].startswith("UNASSIGNED"):
            letter = "U"
        if a[0].startswith("MISSING"):
            letter = "M"
        if a[0].startswith("HELIX"):
            letter = "H"
        if a[0].startswith("SHEET"):
            letter = "B"
        #print(a[1], a[2], "-->", int(seqres_num[int(a[1])-1]), int(seqres_num[int(a[2])-1]))
        for j in range(int(remove_letters(seqres_num[int(a[1])-1])), int(remove_letters(seqres_num[int(a[2])-1]))): # numbering starts at 1 in pdb, so start counting one before, ie 1 is 0
            try:
                ss_placeholder[j] = letter
            except:
                print(f"index: {j}")
                print(f"seqres: {seqres_num[j]}")
                print(f"Error with {uniprot_id}")
                print(f"Annot: {a}")
                print(f"Seq: {disprot_dict[uniprot_id]['seq']}")
                print(f"SS: {len(ss_placeholder)}")
                return False
    return ss_placeholder

# %%
import numpy as np

mobifiles = os.listdir("mobidb_dev_10_2024")

os.makedirs("mobidb_dev_10_2024_SSannotated", exist_ok=True)

stats_dict = dict()

for i, mobifile in enumerate(mobifiles):

    uniprot_id = mobifile.split(".")[0]
    output_json = f"mobidb_dev_10_2024_SSannotated/{uniprot_id}.json"

    if not os.path.exists(output_json):
        #read json
        with open(f"mobidb_dev_10_2024/{mobifile}") as f:
            data = json.load(f)
        
        stats_dict[uniprot_id] = collections.defaultdict(int)
        ss_annot_seqs = collections.defaultdict(dict)
        ss_annot_seqs_list = []
        for k in data.keys():
            if k.startswith("derived-observed-mobi-"):
                #print(k)
                for l in data[k].keys():
                    #print(l, data[k][l])
                    if l == "source_id":
                        pdbid, chain = data[k][l].split("_")
                        #print(pdbid, chain)
                        
                        ### NEW: Omit download part, these are pre-downloaded on get_mobidb_annotations.ipynb
                        #res = requests.get(f"https://data.rcsb.org/rest/v1/core/polymer_entity_instance/{pdbid.upper()}/{chain}")
                        pdb_json = f"mobidb_dev_10_2024/PDB_data/{pdbid}_{chain}.json"
                        with open(pdb_json) as f:
                            datadict = json.load(f)
                        #datadict = json.loads(res.content.decode())
                        seqres_num, annots = parse_pdb_json(datadict, pdbid, chain)
                        if annots:
                            if len(seqres_num) == len(disprot_dict[uniprot_id]['seq']):
                                #print("classic ",pdbid,chain)
                                stats_dict[uniprot_id]["complete"] += 1
                                ss_seq_list = parse_annots_to_seq(annots, disprot_dict, uniprot_id, seqres_num)
                            else:
                                seqnum_max = np.max([int(i) for i in seqres_num])
                                seqlen = len(disprot_dict[uniprot_id]['seq'])
                                if seqnum_max <= seqlen:
                                    stats_dict[uniprot_id]["incomplete"] += 1
                                    ss_seq_list = parse_annots_to_seq2(annots, disprot_dict, uniprot_id, seqres_num)
                                else:
                                    #print(f"length mismatch: {seqlen} and {seqnum_max}")
                                    #### PDB chain is longer than uniprot
                                    stats_dict[uniprot_id]["fail_length"] += 1
                                    continue
                            ss_seq = "".join(ss_seq_list)
                            ss_annot_seqs[uniprot_id][f"{pdbid}_{chain}"] = ss_seq
                        else:
                            #### PDB chain has no annotation
                            stats_dict[uniprot_id]["fail_noannot"] += 1
        print(f'{uniprot_id} : complete={stats_dict[uniprot_id]["complete"]}, incomplete={stats_dict[uniprot_id]["incomplete"]}, fail_length={stats_dict[uniprot_id]["fail_length"]}, fail_noannot={stats_dict[uniprot_id]["fail_noannot"]}')
        
        ss_annot_seqs[uniprot_id]['stats'] = stats_dict[uniprot_id]

        with open(output_json, 'w') as outf:
            json.dump(ss_annot_seqs, outf)
# Out:
# Q9UKV8 : complete=31, incomplete=34, fail_length=0, fail_noannot=0
# Q9HD36 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# Q8K419 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# P05059 : complete=0, incomplete=0, fail_length=0, fail_noannot=1
# B8YB65 : complete=8, incomplete=0, fail_length=0, fail_noannot=0
# Q90VU7 : complete=4, incomplete=3, fail_length=79, fail_noannot=0
# P27782 : complete=0, incomplete=3, fail_length=0, fail_noannot=0
# P52564 : complete=0, incomplete=13, fail_length=2, fail_noannot=0
# Q9UKT5 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# F0ZBA6 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# Q9NQA5 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# O61667 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# P69697 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# Q9UHK0 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# O00308 : complete=0, incomplete=19, fail_length=0, fail_noannot=0
# P0CF51 : complete=0, incomplete=0, fail_length=11, fail_noannot=0
# Q9P2K3-3 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P35193 : complete=0, incomplete=11, fail_length=0, fail_noannot=0
# Q24246 : complete=0, incomplete=7, fail_length=0, fail_noannot=0
# P21952 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# P07766 : complete=22, incomplete=15, fail_length=7, fail_noannot=0
# Q9HCB6 : complete=0, incomplete=9, fail_length=0, fail_noannot=0
# P04972 : complete=13, incomplete=5, fail_length=0, fail_noannot=0
# P35638 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P63045 : complete=0, incomplete=34, fail_length=0, fail_noannot=0
# Q6PHW0 : complete=0, incomplete=0, fail_length=14, fail_noannot=0
# Q04964 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q27934 : complete=0, incomplete=6, fail_length=0, fail_noannot=0
# P04386 : complete=0, incomplete=13, fail_length=0, fail_noannot=0
# Q97W73 : complete=0, incomplete=4, fail_length=0, fail_noannot=0
# Q9H5I1 : complete=0, incomplete=3, fail_length=0, fail_noannot=0
# P80220 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# Q9NK80 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P16458 : complete=1, incomplete=13, fail_length=0, fail_noannot=0
# P04370-5 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q96SD1 : complete=0, incomplete=14, fail_length=2, fail_noannot=0
# Q8N726-1 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P23632 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P21374 : complete=7, incomplete=0, fail_length=0, fail_noannot=0
# Q9SQK3 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# Q16222-2 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# O74718 : complete=0, incomplete=7, fail_length=0, fail_noannot=0
# P60896 : complete=54, incomplete=1, fail_length=0, fail_noannot=0
# P14602 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P06492 : complete=0, incomplete=3, fail_length=0, fail_noannot=0
# P05452 : complete=0, incomplete=4, fail_length=0, fail_noannot=0
# G8HXD9 : complete=0, incomplete=0, fail_length=1, fail_noannot=0
# P21758 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q98325 : complete=0, incomplete=2, fail_length=4, fail_noannot=0
# Q9Y6H6 : complete=4, incomplete=1, fail_length=4, fail_noannot=0
# Q9BS26 : complete=0, incomplete=9, fail_length=0, fail_noannot=0
# Q8ZRP0 : complete=1, incomplete=0, fail_length=0, fail_noannot=0
# P02640 : complete=0, incomplete=49, fail_length=0, fail_noannot=0
# P35813 : complete=1, incomplete=6, fail_length=5, fail_noannot=0
# P04383 : complete=3, incomplete=0, fail_length=0, fail_noannot=0
# P09883 : complete=5, incomplete=42, fail_length=1, fail_noannot=0
# Q54BW5 : complete=0, incomplete=3, fail_length=0, fail_noannot=0
# P02686-5 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P17109 : complete=100, incomplete=6, fail_length=0, fail_noannot=0
# P0A705 : complete=4, incomplete=4, fail_length=0, fail_noannot=0
# O35274 : complete=0, incomplete=5, fail_length=0, fail_noannot=0
# P03496 : complete=0, incomplete=28, fail_length=0, fail_noannot=0
# P0ABQ4 : complete=151, incomplete=12, fail_length=27, fail_noannot=0
# Q09260 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# Q9BQB4 : complete=0, incomplete=4, fail_length=0, fail_noannot=0
# P07805 : complete=0, incomplete=0, fail_length=16, fail_noannot=0
# P56287 : complete=6, incomplete=0, fail_length=0, fail_noannot=0
# P48443 : complete=0, incomplete=6, fail_length=0, fail_noannot=0
# P0AFG0 : complete=45, incomplete=24, fail_length=0, fail_noannot=0
# Q13569 : complete=0, incomplete=25, fail_length=0, fail_noannot=0
# P19880 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# P28325 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# P39926 : complete=0, incomplete=6, fail_length=0, fail_noannot=0
# P19972 : complete=0, incomplete=8, fail_length=0, fail_noannot=0
# P22363 : complete=0, incomplete=8, fail_length=0, fail_noannot=0
# Q928V6 : complete=0, incomplete=13, fail_length=12, fail_noannot=0
# Q1K7R9 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# O33599 : complete=0, incomplete=11, fail_length=0, fail_noannot=0
# Q96B02 : complete=1, incomplete=4, fail_length=0, fail_noannot=0
# Q00987-11 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P18615 : complete=6, incomplete=5, fail_length=0, fail_noannot=0
# P36578 : complete=87, incomplete=12, fail_length=0, fail_noannot=0
# P41352 : complete=517, incomplete=4, fail_length=0, fail_noannot=0
# Q8R316 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# Q14493 : complete=0, incomplete=3, fail_length=0, fail_noannot=0
# P23457 : complete=2, incomplete=1, fail_length=2, fail_noannot=0
# P39286 : complete=3, incomplete=4, fail_length=0, fail_noannot=0
# Q13415 : complete=2, incomplete=9, fail_length=0, fail_noannot=0
# Q13351 : complete=0, incomplete=3, fail_length=0, fail_noannot=0
# P02774 : complete=0, incomplete=9, fail_length=0, fail_noannot=0
# Q9FIX2 : complete=0, incomplete=0, fail_length=1, fail_noannot=0
# Q9DQX7 : complete=0, incomplete=0, fail_length=3, fail_noannot=0
# P00452 : complete=82, incomplete=1, fail_length=0, fail_noannot=0
# Q5ZYC9 : complete=1, incomplete=3, fail_length=0, fail_noannot=0
# P39935 : complete=0, incomplete=6, fail_length=0, fail_noannot=0
# Q8N4Q1 : complete=0, incomplete=1, fail_length=1, fail_noannot=0
# P61073 : complete=0, incomplete=11, fail_length=22, fail_noannot=0
# P30542 : complete=0, incomplete=0, fail_length=6, fail_noannot=0
# Q9Y2Z0 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# Q15185 : complete=3, incomplete=2, fail_length=0, fail_noannot=0
# Q9JK66 : complete=0, incomplete=19, fail_length=0, fail_noannot=0
# P89522 : complete=1, incomplete=4, fail_length=0, fail_noannot=0
# P0AFC7 : complete=25, incomplete=0, fail_length=0, fail_noannot=0
# Q8BPB0 : complete=0, incomplete=15, fail_length=0, fail_noannot=0
# Q92558 : complete=1, incomplete=4, fail_length=0, fail_noannot=0
# Q9NRY2 : complete=2, incomplete=1, fail_length=0, fail_noannot=0
# P24255 : complete=0, incomplete=3, fail_length=1, fail_noannot=0
# Q15797 : complete=0, incomplete=14, fail_length=0, fail_noannot=0
# Q81AN8 : complete=0, incomplete=5, fail_length=0, fail_noannot=0
# P04578 : complete=0, incomplete=288, fail_length=1, fail_noannot=2
# Q9BTT0 : complete=0, incomplete=3, fail_length=0, fail_noannot=0
# O66858 : complete=0, incomplete=7, fail_length=0, fail_noannot=0
# P33328 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P48740-3 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P00736 : complete=0, incomplete=18, fail_length=0, fail_noannot=0
# Q94218-2 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P02309 : complete=23, incomplete=49, fail_length=3, fail_noannot=0
# B7T1D7 : complete=0, incomplete=5, fail_length=0, fail_noannot=0
# Q92973 : complete=0, incomplete=28, fail_length=0, fail_noannot=0
# Q9DDG2 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# A0A1Z3GD08 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q808Y3 : complete=1, incomplete=0, fail_length=0, fail_noannot=0
# Q9UJY5 : complete=0, incomplete=43, fail_length=0, fail_noannot=0
# P15865 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q5D1E8 : complete=0, incomplete=6, fail_length=0, fail_noannot=0
# P09651 : complete=0, incomplete=78, fail_length=0, fail_noannot=105
# O95147 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# Q13426 : complete=38, incomplete=30, fail_length=23, fail_noannot=0
# P19836 : complete=0, incomplete=14, fail_length=0, fail_noannot=0
# P59635 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# P04695 : complete=1, incomplete=24, fail_length=3, fail_noannot=0
# Q9M605 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q5V913 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P0ABH9 : complete=74, incomplete=25, fail_length=12, fail_noannot=0
# Error with 7qe7_T
# Error with 8s4g_T
# Q9UM11 : complete=2, incomplete=3, fail_length=0, fail_noannot=2
# Q14258 : complete=2, incomplete=19, fail_length=0, fail_noannot=0
# P04004 : complete=0, incomplete=10, fail_length=0, fail_noannot=1
# P42224 : complete=0, incomplete=5, fail_length=2, fail_noannot=0
# P14061 : complete=12, incomplete=30, fail_length=0, fail_noannot=0
# P32628 : complete=0, incomplete=14, fail_length=0, fail_noannot=0
# A8CDV5 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P05434 : complete=4, incomplete=2, fail_length=0, fail_noannot=0
# P20893 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P76407 : complete=1, incomplete=0, fail_length=2, fail_noannot=0
# P35236 : complete=0, incomplete=13, fail_length=0, fail_noannot=0
# P75966 : complete=2, incomplete=1, fail_length=0, fail_noannot=0
# Q9I9C0 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# Q10589 : complete=0, incomplete=40, fail_length=16, fail_noannot=0
# Q13501 : complete=0, incomplete=70, fail_length=0, fail_noannot=0
# P36100 : complete=7, incomplete=4, fail_length=13, fail_noannot=0
# Q96PM5 : complete=0, incomplete=5, fail_length=0, fail_noannot=0
# Q8N300 : complete=17, incomplete=11, fail_length=5, fail_noannot=0
# P62805 : complete=346, incomplete=670, fail_length=2, fail_noannot=0
# P20220 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# Q02363 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# P02263 : complete=8, incomplete=9, fail_length=0, fail_noannot=0
# Q59471 : complete=16, incomplete=16, fail_length=0, fail_noannot=0
# Q16630 : complete=0, incomplete=68, fail_length=0, fail_noannot=0
# Q9N4U5 : complete=0, incomplete=6, fail_length=0, fail_noannot=0
# P22239 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# O35625 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# P10636-8 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P00514 : complete=4, incomplete=38, fail_length=1, fail_noannot=0
# P74518 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q13363 : complete=0, incomplete=33, fail_length=0, fail_noannot=0
# P76045 : complete=0, incomplete=15, fail_length=0, fail_noannot=0
# Q9Y5C1 : complete=0, incomplete=3, fail_length=0, fail_noannot=0
# P35256 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# Q02297-10 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P55957 : complete=0, incomplete=24, fail_length=2, fail_noannot=0
# Q05917 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# P01100 : complete=0, incomplete=4, fail_length=0, fail_noannot=0
# P36871 : complete=4, incomplete=22, fail_length=3, fail_noannot=0
# A0A0H2ZP82 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# A0A0H3LBR3 : complete=0, incomplete=2, fail_length=1, fail_noannot=0
# O28362 : complete=2, incomplete=1, fail_length=0, fail_noannot=0
# Q3UND0 : complete=0, incomplete=10, fail_length=0, fail_noannot=0
# P26554 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# Q38151 : complete=3, incomplete=0, fail_length=0, fail_noannot=0
# Q8WUG5 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P09041 : complete=0, incomplete=5, fail_length=0, fail_noannot=0
# P0AE70 : complete=6, incomplete=1, fail_length=26, fail_noannot=0
# P0CU51 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q9BRG1 : complete=2, incomplete=6, fail_length=0, fail_noannot=0
# P17870 : complete=4, incomplete=11, fail_length=5, fail_noannot=0
# P9WHJ5 : complete=15, incomplete=1, fail_length=0, fail_noannot=0
# P49765 : complete=0, incomplete=6, fail_length=1, fail_noannot=0
# P27321 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# Q15796 : complete=0, incomplete=18, fail_length=0, fail_noannot=0
# P45985 : complete=0, incomplete=0, fail_length=6, fail_noannot=0
# Q13469 : complete=0, incomplete=29, fail_length=0, fail_noannot=0
# O14558 : complete=0, incomplete=38, fail_length=8, fail_noannot=0
# Q7Q3R9 : complete=0, incomplete=3, fail_length=0, fail_noannot=0
# P01071 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# A6NI73 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# P81019 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P50477 : complete=9, incomplete=24, fail_length=0, fail_noannot=0
# Q96N21 : complete=0, incomplete=3, fail_length=0, fail_noannot=0
# P0ADC1 : complete=0, incomplete=7, fail_length=0, fail_noannot=0
# Q8NBZ7 : complete=0, incomplete=15, fail_length=0, fail_noannot=0
# Q8ZRW0 : complete=2, incomplete=0, fail_length=0, fail_noannot=0
# Q57904 : complete=0, incomplete=0, fail_length=4, fail_noannot=0
# P56210 : complete=0, incomplete=10, fail_length=2, fail_noannot=0
# Q99LJ8 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P0AG86 : complete=28, incomplete=4, fail_length=0, fail_noannot=0
# Q96EQ8 : complete=2, incomplete=2, fail_length=0, fail_noannot=0
# Q24139 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# P37173 : complete=0, incomplete=19, fail_length=0, fail_noannot=0
# O65934 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# P50097 : complete=7, incomplete=8, fail_length=0, fail_noannot=0
# P10912 : complete=0, incomplete=14, fail_length=3, fail_noannot=0
# P55145 : complete=0, incomplete=3, fail_length=0, fail_noannot=0
# O95391 : complete=6, incomplete=0, fail_length=0, fail_noannot=0
# F1QGH7 : complete=1, incomplete=0, fail_length=0, fail_noannot=0
# Q96AE4 : complete=0, incomplete=13, fail_length=0, fail_noannot=0
# O60356 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q03692 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# O54465 : complete=4, incomplete=1, fail_length=1, fail_noannot=0
# P68466 : complete=3, incomplete=0, fail_length=0, fail_noannot=0
# Q9YIJ1 : complete=1, incomplete=4, fail_length=0, fail_noannot=0
# Q13838 : complete=8, incomplete=12, fail_length=0, fail_noannot=0
# Q58876 : complete=0, incomplete=10, fail_length=0, fail_noannot=0
# Q8WVQ1 : complete=0, incomplete=8, fail_length=0, fail_noannot=0
# P0AD27 : complete=3, incomplete=0, fail_length=1, fail_noannot=0
# P20823 : complete=0, incomplete=12, fail_length=0, fail_noannot=0
# P02545 : complete=0, incomplete=52, fail_length=0, fail_noannot=0
# P04616 : complete=6, incomplete=16, fail_length=0, fail_noannot=0
# Q96PU5 : complete=0, incomplete=29, fail_length=0, fail_noannot=0
# Q9VZU1 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q05344 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# Q01924 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P30429-2 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# O30916 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# F9UST4 : complete=0, incomplete=0, fail_length=102, fail_noannot=0
# Q9CX60 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q06433 : complete=0, incomplete=2, fail_length=8, fail_noannot=0
# P20807 : complete=0, incomplete=16, fail_length=3, fail_noannot=0
# C4M7X2 : complete=0, incomplete=4, fail_length=0, fail_noannot=0
# Q9IH62 : complete=0, incomplete=18, fail_length=7, fail_noannot=0
# Q8RWK8 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P62826 : complete=91, incomplete=96, fail_length=4, fail_noannot=0
# P39748 : complete=2, incomplete=20, fail_length=0, fail_noannot=0
# P40999 : complete=0, incomplete=4, fail_length=0, fail_noannot=0
# Q8WV28 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# P11409 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# Q99958 : complete=0, incomplete=6, fail_length=0, fail_noannot=0
# P06179 : complete=0, incomplete=6, fail_length=0, fail_noannot=0
# Q99ML1 : complete=0, incomplete=3, fail_length=0, fail_noannot=0
# P28324 : complete=0, incomplete=5, fail_length=0, fail_noannot=0
# P30185 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P26447 : complete=28, incomplete=38, fail_length=1, fail_noannot=0
# Q86VN1 : complete=0, incomplete=3, fail_length=0, fail_noannot=0
# O32728 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# P0A903 : complete=23, incomplete=45, fail_length=2, fail_noannot=0
# Q12834 : complete=9, incomplete=7, fail_length=0, fail_noannot=0
# P03069 : complete=0, incomplete=317, fail_length=91, fail_noannot=0
# P43403 : complete=0, incomplete=19, fail_length=1, fail_noannot=0
# B4Y891 : complete=1, incomplete=0, fail_length=0, fail_noannot=0
# Q9BXW4 : complete=0, incomplete=12, fail_length=0, fail_noannot=0
# Q92905 : complete=7, incomplete=15, fail_length=0, fail_noannot=0
# P20849 : complete=0, incomplete=7, fail_length=0, fail_noannot=0
# P44228 : complete=0, incomplete=0, fail_length=1, fail_noannot=0
# Q12287 : complete=3, incomplete=0, fail_length=0, fail_noannot=0
# P06836 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P97303 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P11171 : complete=0, incomplete=6, fail_length=0, fail_noannot=0
# P61244-2 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P20239 : complete=0, incomplete=4, fail_length=0, fail_noannot=0
# P41780 : complete=0, incomplete=0, fail_length=4, fail_noannot=0
# E6PBU9 : complete=4, incomplete=0, fail_length=0, fail_noannot=0
# Q7Z094 : complete=2, incomplete=1, fail_length=0, fail_noannot=0
# Q3E840 : complete=1, incomplete=1, fail_length=8, fail_noannot=0
# Q8GUI6 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# Q13542 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# P62330 : complete=5, incomplete=14, fail_length=8, fail_noannot=2
# Q9SKB2 : complete=0, incomplete=6, fail_length=0, fail_noannot=0
# Q12306 : complete=1, incomplete=13, fail_length=40, fail_noannot=0
# P9WI73 : complete=0, incomplete=5, fail_length=0, fail_noannot=0
# P11157 : complete=5, incomplete=0, fail_length=0, fail_noannot=1
# A0A097F4I8 : complete=2, incomplete=0, fail_length=0, fail_noannot=0
# O00189 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# Q8IUQ4 : complete=0, incomplete=19, fail_length=0, fail_noannot=0
# Q9BUH6 : complete=12, incomplete=8, fail_length=0, fail_noannot=0
# P0ABE0 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q01080 : complete=39, incomplete=7, fail_length=0, fail_noannot=0
# P34087 : complete=92, incomplete=0, fail_length=17, fail_noannot=3
# P17181 : complete=0, incomplete=4, fail_length=0, fail_noannot=0
# Q9I832 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P10279 : complete=0, incomplete=6, fail_length=1, fail_noannot=4
# Q5XJY5 : complete=17, incomplete=0, fail_length=0, fail_noannot=0
# Q9Y296 : complete=1, incomplete=1, fail_length=2, fail_noannot=0
# P36080 : complete=3, incomplete=0, fail_length=0, fail_noannot=0
# P15825 : complete=64, incomplete=2, fail_length=0, fail_noannot=0
# P40019 : complete=0, incomplete=3, fail_length=0, fail_noannot=0
# P05451 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# P13010 : complete=38, incomplete=23, fail_length=0, fail_noannot=0
# P40458 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# P16892 : complete=9, incomplete=0, fail_length=0, fail_noannot=0
# Q8IW19 : complete=0, incomplete=30, fail_length=0, fail_noannot=0
# Q14722 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P20879 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q93P54 : complete=0, incomplete=11, fail_length=0, fail_noannot=0
# P49736 : complete=8, incomplete=20, fail_length=0, fail_noannot=0
# P22059 : complete=0, incomplete=5, fail_length=0, fail_noannot=0
# P23771 : complete=0, incomplete=4, fail_length=0, fail_noannot=0
# P45976 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# Q96T21 : complete=2, incomplete=0, fail_length=0, fail_noannot=0
# P27694 : complete=1, incomplete=44, fail_length=0, fail_noannot=0
# O60493 : complete=0, incomplete=11, fail_length=0, fail_noannot=0
# Q13148 : complete=61, incomplete=104, fail_length=0, fail_noannot=16
# P56777 : complete=2, incomplete=2, fail_length=0, fail_noannot=0
# P41351 : complete=517, incomplete=4, fail_length=0, fail_noannot=0
# Q77M43 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# A1B8N7 : complete=1, incomplete=0, fail_length=0, fail_noannot=0
# P49235 : complete=0, incomplete=18, fail_length=0, fail_noannot=0
# Q91V27 : complete=0, incomplete=5, fail_length=0, fail_noannot=0
# O96013 : complete=0, incomplete=63, fail_length=0, fail_noannot=0
# Q05919 : complete=0, incomplete=0, fail_length=1, fail_noannot=0
# O73557 : complete=1, incomplete=2, fail_length=0, fail_noannot=0
# O75936 : complete=7, incomplete=10, fail_length=0, fail_noannot=0
# Q92837 : complete=2, incomplete=10, fail_length=0, fail_noannot=0
# Q9CQK7 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q15637 : complete=1, incomplete=13, fail_length=0, fail_noannot=0
# Q9NP98 : complete=0, incomplete=3, fail_length=0, fail_noannot=0
# O60508 : complete=19, incomplete=1, fail_length=0, fail_noannot=0
# P08033 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q06208 : complete=0, incomplete=9, fail_length=0, fail_noannot=0
# P0ACF8 : complete=0, incomplete=8, fail_length=0, fail_noannot=0
# P46108 : complete=1, incomplete=9, fail_length=0, fail_noannot=0
# P37028 : complete=0, incomplete=5, fail_length=19, fail_noannot=0
# P35269 : complete=55, incomplete=9, fail_length=0, fail_noannot=0
# Q980M2 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# Q68DK7 : complete=0, incomplete=10, fail_length=0, fail_noannot=0
# Q9Y5S9 : complete=8, incomplete=16, fail_length=2, fail_noannot=0
# P12950 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q05140 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P0A6H5 : complete=10, incomplete=72, fail_length=0, fail_noannot=0
# P36894 : complete=0, incomplete=20, fail_length=1, fail_noannot=0
# Q05158 : complete=0, incomplete=4, fail_length=0, fail_noannot=0
# A0KJC7 : complete=0, incomplete=14, fail_length=0, fail_noannot=0
# Q99623 : complete=0, incomplete=7, fail_length=0, fail_noannot=0
# P42758 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q9IK92 : complete=0, incomplete=38, fail_length=0, fail_noannot=0
# Q53TN4 : complete=0, incomplete=0, fail_length=2, fail_noannot=0
# P10415 : complete=0, incomplete=79, fail_length=0, fail_noannot=0
# Error with 8pic_A
# Error with 8pic_B
# Error with 8pic_C
# Error with 8pic_D
# Error with 8pic_E
# Error with 8pic_F
# Error with 8pic_G
# Error with 8pic_H
# Error with 8pic_I
# Error with 8pic_J
# P37840 : complete=838, incomplete=83, fail_length=7, fail_noannot=16
# O43070 : complete=0, incomplete=9, fail_length=4, fail_noannot=0
# O24172 : complete=1, incomplete=0, fail_length=0, fail_noannot=0
# Q68J44 : complete=0, incomplete=2, fail_length=0, fail_noannot=0
# P10922 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q15113 : complete=0, incomplete=4, fail_length=0, fail_noannot=0
# Q716H0 : complete=60, incomplete=8, fail_length=0, fail_noannot=0
# Q9NPI8 : complete=0, incomplete=7, fail_length=0, fail_noannot=0
# P0DTC4 : complete=0, incomplete=16, fail_length=10, fail_noannot=0
# Q9RSK0 : complete=14, incomplete=4, fail_length=0, fail_noannot=0
# Q07097 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P83949 : complete=0, incomplete=6, fail_length=0, fail_noannot=0
# P17931 : complete=0, incomplete=132, fail_length=7, fail_noannot=0
# P49023 : complete=0, incomplete=56, fail_length=2, fail_noannot=0
# Q9BRX5 : complete=9, incomplete=3, fail_length=1, fail_noannot=0
# O01479 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# A0MHA3 : complete=0, incomplete=6, fail_length=0, fail_noannot=0
# P15309 : complete=0, incomplete=9, fail_length=14, fail_noannot=1
# P40357 : complete=0, incomplete=6, fail_length=0, fail_noannot=0
# C6ECL5 : complete=0, incomplete=4, fail_length=0, fail_noannot=0
# P53853 : complete=12, incomplete=8, fail_length=0, fail_noannot=0
# A7UMX5 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# Q9NR00 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P22216 : complete=0, incomplete=45, fail_length=0, fail_noannot=0
# P0A9H7 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# P07237 : complete=1, incomplete=18, fail_length=0, fail_noannot=0
# P50402 : complete=0, incomplete=7, fail_length=0, fail_noannot=0
# Q13563 : complete=8, incomplete=41, fail_length=0, fail_noannot=0
# Q9UBK2 : complete=0, incomplete=40, fail_length=0, fail_noannot=0
# P11912 : complete=0, incomplete=3, fail_length=1, fail_noannot=1
# P51513 : complete=0, incomplete=3, fail_length=0, fail_noannot=0
# Q62902 : complete=0, incomplete=5, fail_length=0, fail_noannot=0
# P53905 : complete=18, incomplete=1, fail_length=0, fail_noannot=0
# S7W634 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# P39015 : complete=47, incomplete=27, fail_length=1, fail_noannot=0
# P84022 : complete=0, incomplete=18, fail_length=0, fail_noannot=0
# O15273 : complete=2, incomplete=1, fail_length=0, fail_noannot=0
# P36106 : complete=1, incomplete=3, fail_length=0, fail_noannot=0
# Q42521 : complete=6, incomplete=0, fail_length=0, fail_noannot=0
# P68390 : complete=2, incomplete=39, fail_length=0, fail_noannot=0
# Q05080 : complete=0, incomplete=1, fail_length=0, fail_noannot=0
# C6ZFX3 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P31109 : complete=0, incomplete=3, fail_length=0, fail_noannot=0
# P21815 : complete=0, incomplete=0, fail_length=0, fail_noannot=0
# P0AFF6 : complete=14, incomplete=24, fail_length=1, fail_noannot=0

# %%
## implement majority voting, only if 90% or 75% of majority agrees
annotfiles = [f for f in os.listdir("mobidb_dev_10_2024_SSannotated") if f.endswith("json")]

outdir_consensus= "mobidb_dev_10_2024_SSannotated/consensus"
os.makedirs(outdir_consensus, exist_ok=True)


def get_majority_seq(disprot_dict, uniprot_id, ss_annot_seqs_list, majority_value=0.75, use_incomplete=True):
    if use_incomplete:
        total_seqs = len(ss_annot_seqs_list)
        ss_seqs_list = ss_annot_seqs_list
    else:
        ss_seqs_list = [s for s in ss_annot_seqs_list if "-" not in s]
        total_seqs = len(ss_seqs_list)
    #print(uniprot_id, total_seqs)
    seq = disprot_dict[uniprot_id]['seq']
    letter_ix = ["M", "U", "H", "B"]
    majority_seq = []
    majority_value = 0.75
    if len(ss_seqs_list) == 0:
        return ["-" for k in range(len(seq))]
    else:
        for i in range(len(seq)):
            counts = np.array([0,0,0,0]) # M, U, H, B
            for j in range(total_seqs):
                letter = ss_seqs_list[j][i]
                if letter == "M":
                    counts[0] += 1
                elif letter == "U":
                    counts[1] += 1
                elif letter == "H":
                    counts[2] += 1
                elif letter == "B":
                    counts[3] += 1
            majority = np.max(counts)
            if majority >= majority_value*total_seqs:
                winner = np.where(counts == np.max(counts))[0][0]
                majority_seq.append(letter_ix[winner])
            else:
                majority_seq.append("-")
        return majority_seq

for i, mobifile in enumerate(annotfiles):
    ss_annot_seqs_cons = collections.defaultdict(dict)

    uniprot_id = mobifile.split(".")[0]
    # if uniprot_id.endswith("consensus"):
    #     continue
    with open(f"mobidb_dev_10_2024_SSannotated/{mobifile}") as f:
        ss_annot_dict = json.load(f)
    ss_annot_seqs_list = [ss_annot_dict[uniprot_id][k] for k in ss_annot_dict[uniprot_id].keys() if k!="stats"]
    
    mv = 0.75
    use_incomp = True
    label=f"consensus_{mv:.2f}_inc"
    majority_seq = get_majority_seq(disprot_dict, uniprot_id, ss_annot_seqs_list, use_incomplete=use_incomp)
    ss_annot_seqs_cons[uniprot_id][label] = "".join(majority_seq)

    mv = 0.75
    use_incomp = False
    label=f"consensus_{mv:.2f}"
    majority_seq = get_majority_seq(disprot_dict, uniprot_id, ss_annot_seqs_list, use_incomplete=use_incomp)
    ss_annot_seqs_cons[uniprot_id][label] = "".join(majority_seq)

    with open(f"{outdir_consensus}/{uniprot_id}_consensus.json", 'w') as outf:
        json.dump(ss_annot_seqs_cons, outf)

# %%
def get_majority_seq(disprot_dict, uniprot_id, ss_annot_seqs_list, majority_value=0.75, use_incomplete=True):
    if use_incomplete:
        total_seqs = len(ss_annot_seqs_list)
        ss_seqs_list = ss_annot_seqs_list
    else:
        print("using only complete")
        ss_seqs_list = [s for s in ss_annot_seqs_list if "-" not in s]
        total_seqs = len(ss_seqs_list)
    #print(uniprot_id, total_seqs)
    seq = disprot_dict[uniprot_id]['seq']
    letter_ix = ["M", "U", "H", "B"]
    majority_seq = []
    majority_value = 0.75
    if len(ss_seqs_list) == 0:
        return ["-" for k in range(len(seq))]
    else:
        for i in range(len(seq)):
            counts = np.array([0,0,0,0]) # M, U, H, B
            for j in range(total_seqs):
                letter = ss_seqs_list[j][i]
                if letter == "M":
                    counts[0] += 1
                elif letter == "U":
                    counts[1] += 1
                elif letter == "H":
                    counts[2] += 1
                elif letter == "B":
                    counts[3] += 1
            majority = np.max(counts)
            if majority >= majority_value*total_seqs:
                winner = np.where(counts == np.max(counts))[0][0]
                majority_seq.append(letter_ix[winner])
            else:
                majority_seq.append("-")
        return majority_seq

mv = 0.75
use_incomp = False
label=f"consensus_{mv:.2f}"
uniprot_id="P03265"

with open(f"mobidb_dev_10_2024_SSannotated/{uniprot_id}.json") as f:
    ss_annot_dict = json.load(f)
ss_annot_seqs_list = [ss_annot_dict[uniprot_id][k] for k in ss_annot_dict[uniprot_id].keys() if k!="stats"]


majority_seq = get_majority_seq(disprot_dict, uniprot_id, ss_annot_seqs_list, use_incomplete=use_incomp)
print(majority_seq)
# Out:
# using only complete
# []
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-', '-']

# %%
#### Example of incomplete pdb protein

def parse_annots_to_seq2(annot, disprot_dict, uniprot_id, seqres_num):
    ss_placeholder = ["-" for i in range(len(disprot_dict[uniprot_id]['seq']))]
    #seqres_num = ssresnum_list[i]
    for a in annot:
        letter = "-"
        if a[0].startswith("UNASSIGNED"):
            letter = "U"
        if a[0].startswith("MISSING"):
            letter = "M"
        if a[0].startswith("HELIX"):
            letter = "H"
        if a[0].startswith("SHEET"):
            letter = "B"
        #print(a[1], a[2], "-->", int(seqres_num[int(a[1])-1]), int(seqres_num[int(a[2])-1]))
        for j in range(int(seqres_num[int(a[1])-1]), int(seqres_num[int(a[2])-1])): # numbering starts at 1 in pdb, so start counting one before, ie 1 is 0
            try:
                ss_placeholder[j] = letter
            except:
                print(f"index: {j}")
                print(f"seqres: {seqres_num[j]}")
                print(f"Error with {uniprot_id}")
                print(f"Annot: {a}")
                print(f"Seq: {disprot_dict[uniprot_id]['seq']}")
                print(f"SS: {len(ss_placeholder)}")
                return False
    return ss_placeholder

pdbid = "4fro"
chain = "A"
print(pdbid, chain)
res = requests.get(f"https://data.rcsb.org/rest/v1/core/polymer_entity_instance/{pdbid.upper()}/{chain}")
datadict = json.loads(res.content.decode())
seqres_num, annots = parse_pdb_json(datadict, pdbid, chain)
# try:
#     assert len(seqres_num) == len(disprot_dict[uniprot_id]['seq'])
# except AssertionError:
#     print("---> ERROR:", uniprot_id, pdbid, chain, len(seqres_num), len(disprot_dict[uniprot_id]['seq']))
#     continue      
if annots:
    ss_seq_list = parse_annots_to_seq(annots, disprot_dict, uniprot_id, seqres_num)
    seqnum_max = np.max([int(i) for i in seqres_num])
    seqlen = len(disprot_dict[uniprot_id]['seq'])
    if seqnum_max > seqlen:
        print(f"length mismatch: {seqlen} and {seqnum_max}")
        raise
    ss_seq_list2 = parse_annots_to_seq2(annots, disprot_dict, uniprot_id, seqres_num)
    ss_seq = "".join(ss_seq_list)
    ss_seq2 = "".join(ss_seq_list2)
    print(ss_seq)
    print(ss_seq2)
# Out:
# 4fro A
# length mismatch: 354 and 355
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-70-68f2478166ee> in <cell line: 39>()
#      43     if seqnum_max > seqlen:
#      44         print(f"length mismatch: {seqlen} and {seqnum_max}")
# ---> 45         raise
#      46     ss_seq_list2 = parse_annots_to_seq2(annots, disprot_dict, uniprot_id, seqres_num)
#      47     ss_seq = "".join(ss_seq_list)
#
# RuntimeError: No active exception to reraise
